# %% [markdown]
# # Análise Exploratória
# Arquivo destinada à exploração do dataset ("E1.csv")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option("display.max_columns", None)

# %%
df24_25 = pd.read_csv("../data/premier_24_25.csv")
df24_25['Season'] = 24
df24_25.iloc[[0, -1]]
# Out:
#     Div        Date   Time    HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    E0  16/08/2024  20:00  Man United     Fulham     1     0   H     0     0
# 379  E0  25/05/2025  16:00      Wolves  Brentford     1     1   D     0     1
#
#     HTR   Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  \
# 0     D   R Jones  14  10    5    2  12  10   7   8   2   3   0   0    1.6
# 379   A  C Pawson  18  13    6    7   7   9   8   3   2   1   0   0    2.7
#
#      B365D  B365A  BWH  BWD   BWA   BFH   BFD   BFA   PSH   PSD   PSA   WHH  \
# 0      4.2   5.25  1.6  4.4  5.25  1.60  4.33  5.00  1.63  4.38  5.30  1.65
# 379    3.7   2.45  NaN  NaN   NaN  2.75  3.60  2.45  2.74  3.83  2.45   NaN
#
#      WHD  WHA  1XBH  1XBD  1XBA  MaxH  MaxD  MaxA  AvgH  AvgD  AvgA  BFEH  \
# 0    4.2  5.0  1.68  4.32  5.03  1.68  4.50  5.50  1.62  4.36  5.15  1.66
# 379  NaN  NaN  2.77  3.85  2.47  2.77  3.85  2.48  2.71  3.76  2.43  2.86
#
# ...

# %%
df23_24 = pd.read_csv("../data/premier_23_24.csv")
df23_24['Season'] = 23
df23_24.iloc[[0, -1]]
# Out:
#     Div        Date   Time          HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  11/08/2023  20:00           Burnley   Man City     0     3   A     0
# 379  E0  19/05/2024  16:00  Sheffield United  Tottenham     0     3   A     0
#
#      HTAG HTR   Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  \
# 0       2   A  C Pawson   6  17    1    8  11   8   6   5   0   0   1   0
# 379     1   A  A Madley   6  18    1    9  11   9   2   6   2   0   0   0
#
#      B365H  B365D  B365A   BWH   BWD   BWA  IWH  IWD   IWA   PSH   PSD   PSA  \
# 0      8.0    5.5   1.33  8.75  5.25  1.34  8.0  5.5  1.35  8.58  5.51  1.37
# 379    7.0    6.0   1.33  7.25  6.00  1.33  NaN  NaN   NaN  7.16  6.00  1.35
#
#      WHH  WHD   WHA  VCH   VCD   VCA  MaxH  MaxD  MaxA  AvgH  AvgD  AvgA  \
# 0    8.0  5.0  1.25  9.5  5.25  1.33   9.5  5.68  1.39  9.02  5.35  1.35
# 379  7.5  6.0  1.30  7.5  5.75  1.30   7.9  6.34  1.39  7.32  6.04  1.35
#
# ...

# %%
df22_23 = pd.read_csv("../data/premier_22_23.csv")
df22_23['Season'] = 22
df22_23.iloc[[0, -1]]
# Out:
#     Div        Date   Time        HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  05/08/2022  20:00  Crystal Palace    Arsenal     0     2   A     0
# 379  E0  28/05/2023  16:30     Southampton  Liverpool     4     4   D     2
#
#      HTAG HTR    Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  \
# 0       1   A   A Taylor  10  10    2    2  16  11   3   5   1   2   0   0
# 379     2   D  D England  15  30   10    8   4  10   2   9   0   2   0   0
#
#      B365H  B365D  B365A   BWH  BWD   BWA   IWH   IWD   IWA   PSH   PSD   PSA  \
# 0      4.2   3.60   1.85  4.33  3.5  1.87  4.30  3.55  1.85  4.50  3.65  1.89
# 379    6.5   4.75   1.44  6.75  5.0  1.42  6.25  5.00  1.45  6.68  5.29  1.43
#
#      WHH   WHD   WHA  VCH  VCD   VCA  MaxH  MaxD  MaxA  AvgH  AvgD  AvgA  \
# 0    4.4  3.50  1.83  4.6  3.5  1.87   4.6  3.78  1.95  4.39  3.59  1.88
# 379  6.0  4.75  1.33  7.0  5.0  1.40   7.1  5.60  1.46  6.74  5.20  1.42
#
# ...

# %%
df21_22 = pd.read_csv("../data/premier_21_22.csv")
df21_22['Season'] = 21
df21_22.iloc[[0, -1]]
# Out:
#     Div        Date   Time   HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    E0  13/08/2021  20:00  Brentford    Arsenal     2     0   H     1     0
# 379  E0  22/05/2022  16:00    Norwich  Tottenham     0     5   A     0     2
#
#     HTR     Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  \
# 0     H    M Oliver   8  22    3    4  12   8   2   5   0   0   0   0    4.0
# 379   A  C Kavanagh   9  19    0   13  13   7   3   2   3   1   0   0    9.5
#
#      B365D  B365A   BWH  BWD   BWA   IWH   IWD   IWA    PSH   PSD   PSA   WHH  \
# 0      3.4   1.95   4.0  3.5  1.95   3.8  3.40  2.05   4.05  3.46  2.05   4.0
# 379    6.5   1.25  11.0  6.5  1.24  11.0  6.25  1.25  11.20  6.23  1.27  10.0
#
#      WHD   WHA   VCH  VCD   VCA   MaxH  MaxD  MaxA   AvgH  AvgD  AvgA  \
# 0    3.4  1.90   4.1  3.4  2.00   4.62  3.72  2.10   4.02  3.43  2.02
# 379  6.0  1.25  11.5  6.0  1.22  13.00  7.00  1.29  11.19  6.45  1.26
#
# ...

# %%
df20_21 = pd.read_csv("../data/premier_20_21.csv")
df20_21['Season'] = 20
df20_21.iloc[[0, -1]]
# Out:
#     Div        Date   Time HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    E0  12/09/2020  12:30   Fulham     Arsenal     0     3   A     0     1
# 379  E0  23/05/2021  16:00   Wolves  Man United     1     2   A     1     2
#
#     HTR     Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  \
# 0     A  C Kavanagh   5  13    2    6  12  12   2   3   2   2   0   0    6.0
# 379   A      M Dean  14   9    4    4  14   3   6   2   4   1   0   0    2.5
#
#      B365D  B365A  BWH   BWD   BWA   IWH  IWD   IWA   PSH   PSD   PSA   WHH  \
# 0     4.33   1.53  5.5  4.25  1.57  6.00  3.9  1.57  6.16  4.51  1.56  6.50
# 379   3.50   2.70  2.5  3.60  2.70  2.55  3.6  2.65  2.59  3.78  2.70  2.55
#
#      WHD   WHA  VCH  VCD   VCA  MaxH  MaxD  MaxA  AvgH  AvgD  AvgA  B365>2.5  \
# 0    4.2  1.53  6.5  4.2  1.55  6.55  4.55  1.60  5.94  4.34  1.55      1.72
# 379  3.5  2.70  2.5  3.5  2.75  2.63  3.78  2.81  2.53  3.63  2.69      1.72
#
# ...

# %%
df19_20 = pd.read_csv("../data/premier_19_20.csv")
df19_20['Season'] = 19
df19_20.iloc[[0, -1]]
# Out:
#     Div        Date   Time   HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  09/08/2019  20:00  Liverpool      Norwich     4     1   H     4
# 379  E0  26/07/2020  16:00   West Ham  Aston Villa     1     1   D     0
#
#      HTAG HTR   Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  \
# 0       0   H  M Oliver  15  12    7    5   9   9  11   2   0   2   0   0
# 379     0   D  M Oliver  10  13    1    4  16  13   0   7   2   1   0   0
#
#      B365H  B365D  B365A   BWH   BWD   BWA   IWH  IWD   IWA   PSH   PSD  \
# 0     1.14   10.0   19.0  1.14  8.25  18.5  1.15  8.0  18.0  1.15  9.59
# 379   3.00    3.6    2.3  3.00  3.50   2.3  3.05  3.4   2.3  3.12  3.62
#
#        PSA   WHH  WHD   WHA   VCH  VCD    VCA  MaxH   MaxD   MaxA  AvgH  AvgD  \
# 0    18.05  1.12  8.5  21.0  1.14  9.5  23.00  1.16  10.00  23.00  1.14  8.75
# 379   2.31  3.00  3.6   2.3  3.10  3.6   2.25  3.20   3.82   2.36  3.05  3.57
#
# ...

# %%
""" 
Verificando consistência entre as colunas do dataset
 """
dfs = [
    df19_20,
    df20_21,
    df21_22,
    df22_23,
    df23_24,
    df24_25
]

for i in range(len(dfs)-1):
    df1 = dfs[i]
    for j in range(i+1, len(dfs)):
        df2 = dfs[j]

        print(f"\n\n{df1['Date'][0].split(sep='/')[-1]} vs {df2['Date'][0].split(sep='/')[-1]}")

        # Colunas diferentes entre 2 datasets
        for col in df1.columns:
            if col not in df2.columns:
                print(f"\t{col}", sep= " ")
# Out:
# 2019 vs 2020
#
#
# 2019 vs 2021
#
#
# 2019 vs 2022
#
#
# 2019 vs 2023
#
#
# 2019 vs 2024
# 	IWH
# 	IWD
# 	IWA
# 	VCH
# 	VCD
# 	VCA
# 	IWCH
# 	IWCD
# 	IWCA
# 	VCCH
# 	VCCD
# 	VCCA
#
#
# 2020 vs 2021
#
#
# 2020 vs 2022
#
#
# 2020 vs 2023
#
#
# 2020 vs 2024
# 	IWH
# 	IWD
# 	IWA
# 	VCH
# 	VCD
# 	VCA
# 	IWCH
# 	IWCD
# 	IWCA
# 	VCCH
# 	VCCD
# 	VCCA
#
#
# 2021 vs 2022
#
#
# 2021 vs 2023
#
#
# 2021 vs 2024
# 	IWH
# 	IWD
# 	IWA
# 	VCH
# 	VCD
# 	VCA
# 	IWCH
# 	IWCD
# 	IWCA
# 	VCCH
# 	VCCD
# 	VCCA
#
#
# 2022 vs 2023
#
#
# 2022 vs 2024
# 	IWH
# 	IWD
# 	IWA
# 	VCH
# 	VCD
# 	VCA
# 	IWCH
# 	IWCD
# 	IWCA
# 	VCCH
# 	VCCD
# 	VCCA
#
#
# 2023 vs 2024
# 	IWH
# 	IWD
# 	IWA
# 	VCH
# 	VCD
# 	VCA
# 	IWCH
# 	IWCD
# 	IWCA
# 	VCCH
# 	VCCD
# 	VCCA

# %% [markdown]
# O dataset de 24/25 além de ter colunas extras, também não apresenta algumas colunas dos datasets antigos. Todas essas inconsistências não são relevantes de manter para o trabalho.
# - Representam casas de apostas extras. (Ver [legenda](legenda_colunas.md) para consultar as colunas a serem consideradas.)

# %%
for df in dfs:
    print(f" {df['Date'].iloc[0]} {"\n"} {df.info(verbose= True, show_counts=True)} {"\n\n\n"}")
df20_21.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 107 columns):
#  #    Column     Non-Null Count  Dtype
# ---   ------     --------------  -----
#  0    Div        380 non-null    object
#  1    Date       380 non-null    object
#  2    Time       380 non-null    object
#  3    HomeTeam   380 non-null    object
#  4    AwayTeam   380 non-null    object
#  5    FTHG       380 non-null    int64
#  6    FTAG       380 non-null    int64
#  7    FTR        380 non-null    object
#  8    HTHG       380 non-null    int64
#  9    HTAG       380 non-null    int64
#  10   HTR        380 non-null    object
#  11   Referee    380 non-null    object
#  12   HS         380 non-null    int64
#  13   AS         380 non-null    int64
#  14   HST        380 non-null    int64
#  15   AST        380 non-null    int64
#  16   HF         380 non-null    int64
#  17   AF         380 non-null    int64
#  18   HC         380 non-null    int64
# ...

# %%
df_full = pd.concat(dfs, ignore_index= True)

df_full.head()
# Out:
#   Div        Date   Time        HomeTeam          AwayTeam  FTHG  FTAG FTR  \
# 0  E0  09/08/2019  20:00       Liverpool           Norwich     4     1   H
# 1  E0  10/08/2019  12:30        West Ham          Man City     0     5   A
# 2  E0  10/08/2019  15:00     Bournemouth  Sheffield United     1     1   D
# 3  E0  10/08/2019  15:00         Burnley       Southampton     3     0   H
# 4  E0  10/08/2019  15:00  Crystal Palace           Everton     0     0   D
#
#    HTHG  HTAG HTR   Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  \
# 0     4     0   H  M Oliver  15  12    7    5   9   9  11   2   0   2   0   0
# 1     0     1   A    M Dean   5  14    3    9   6  13   1   1   2   2   0   0
# 2     0     0   D  K Friend  13   8    3    3  10  19   3   4   2   1   0   0
# 3     0     0   D   G Scott  10  11    4    3   6  12   2   7   0   0   0   0
# 4     0     0   D    J Moss   6  10    2    3  16  14   6   2   2   1   0   1
#
# ...

# %%
# ver legenda_colunas.md

selected_features = [
    "Div",
    "Season",
    "Date",
    "Time",
    "HomeTeam",
    "AwayTeam",
    "FTHG",   
    "FTAG",   
    "FTR",    
    "HTHG",
    "HTAG",
    "HTR",
    "Referee",
    "HS",
    "AS",
    "HST",
    "AST",
    "HC",
    "AC",
    "HF",
    "AF",
    "HY",
    "AY",
    "HR",
    "AR",
    "B365H",
    "B365D",
    "B365A",
    "PSD",   
    "PSA",   
    "PSH",   
    "MaxH",
    "MaxD",
    "MaxA",
    "AvgH",
    "AvgD",
    "AvgA",
    "B365>2.5",
    "B365<2.5",
    "P>2.5",
    "P<2.5",
    "Max>2.5",
    "Max<2.5",
    "Avg>2.5",
    "Avg<2.5",
    "B365AHH",
    "B365AHA",
    "PAHH",
    "PAHA",
    "MaxAHH",
    "MaxAHA",
    "AvgAHH",
    "AvgAHA"
]

# %%
# Checando consistência da escolha

df_full[selected_features].info(verbose= True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2280 entries, 0 to 2279
# Data columns (total 53 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Div       2280 non-null   object
#  1   Season    2280 non-null   int64
#  2   Date      2280 non-null   object
#  3   Time      2280 non-null   object
#  4   HomeTeam  2280 non-null   object
#  5   AwayTeam  2280 non-null   object
#  6   FTHG      2280 non-null   int64
#  7   FTAG      2280 non-null   int64
#  8   FTR       2280 non-null   object
#  9   HTHG      2280 non-null   int64
#  10  HTAG      2280 non-null   int64
#  11  HTR       2280 non-null   object
#  12  Referee   2280 non-null   object
#  13  HS        2280 non-null   int64
#  14  AS        2280 non-null   int64
#  15  HST       2280 non-null   int64
#  16  AST       2280 non-null   int64
#  17  HC        2280 non-null   int64
#  18  AC        2280 non-null   int64
#  19  HF        2280 non-null   int64
# ...

# %% [markdown]
# Praticamente todas as colunas estão completas. "P>2.5 e P<2.5", odds da Pinnacle para mais de 2.5 gols possuem 10 instâncias não preenchidas que podem ser dropadas.

# %%
# Limpando colunas extras

df_full = df_full.drop(columns= [col for col in df_full.columns if col not in selected_features], axis=1)

df_full.iloc[[0, -1]]
# Out:
#      Div        Date   Time   HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0     E0  09/08/2019  20:00  Liverpool    Norwich     4     1   H     4     0
# 2279  E0  25/05/2025  16:00     Wolves  Brentford     1     1   D     0     1
#
#      HTR   Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  \
# 0      H  M Oliver  15  12    7    5   9   9  11   2   0   2   0   0   1.14
# 2279   A  C Pawson  18  13    6    7   7   9   8   3   2   1   0   0   2.70
#
#       B365D  B365A   PSH   PSD    PSA  MaxH   MaxD   MaxA  AvgH  AvgD   AvgA  \
# 0      10.0  19.00  1.15  9.59  18.05  1.16  10.00  23.00  1.14  8.75  19.83
# 2279    3.7   2.45  2.74  3.83   2.45  2.77   3.85   2.48  2.71  3.76   2.43
#
#       B365>2.5  B365<2.5  P>2.5  P<2.5  Max>2.5  Max<2.5  Avg>2.5  Avg<2.5  \
# 0         1.40       3.0   1.40   3.11     1.45     3.11     1.41     2.92
# 2279      1.53       2.5   1.53   2.56     1.53     2.63     1.50     2.55
#
# ...

# %%
df_full = df_full[['Div', 'Season', 'Date', 'Time', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 
                   'FTR', 'HTHG', 'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 
                   'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 'B365H', 'B365D', 'B365A', 'PSH',
                   'PSD', 'PSA', 'MaxH', 'MaxD', 'MaxA', 'AvgH', 'AvgD', 'AvgA', 'B365>2.5', 
                   'B365<2.5', 'P>2.5', 'P<2.5', 'Max>2.5', 'Max<2.5', 'Avg>2.5', 'Avg<2.5', 'B365AHH', 'B365AHA', 
                   'PAHH', 'PAHA', 'MaxAHH', 'MaxAHA', 'AvgAHH', 'AvgAHA']]
df_full.head()
# Out:
#   Div  Season        Date   Time        HomeTeam          AwayTeam  FTHG  \
# 0  E0      19  09/08/2019  20:00       Liverpool           Norwich     4
# 1  E0      19  10/08/2019  12:30        West Ham          Man City     0
# 2  E0      19  10/08/2019  15:00     Bournemouth  Sheffield United     1
# 3  E0      19  10/08/2019  15:00         Burnley       Southampton     3
# 4  E0      19  10/08/2019  15:00  Crystal Palace           Everton     0
#
#    FTAG FTR  HTHG  HTAG HTR   Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  \
# 0     1   H     4     0   H  M Oliver  15  12    7    5   9   9  11   2   0
# 1     5   A     0     1   A    M Dean   5  14    3    9   6  13   1   1   2
# 2     1   D     0     0   D  K Friend  13   8    3    3  10  19   3   4   2
# 3     0   H     0     0   D   G Scott  10  11    4    3   6  12   2   7   0
# 4     0   D     0     0   D    J Moss   6  10    2    3  16  14   6   2   2
#
# ...

# %%
df_full.shape
# Out:
# (2280, 53)

# %%
df_full.to_csv("../data/premier_completo_19_25.csv", index= False)
