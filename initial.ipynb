# %% [markdown]
# # Configuração

# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('E1.csv')

# %% [markdown]
# # Estrutura

# %%
df.shape
# Out:
# (1494, 21)

# %%
df.head()
# Out:
#    game_id game_event_type possession_event_type  period  timestamp  \
# 0     3812             OTB                  SHOT       1    186.119
# 1     3812             OTB                  SHOT       1    376.610
# 2     3812             OTB                  SHOT       1    669.436
# 3     3812             OTB                  SHOT       1    915.516
# 4     3812             OTB                  SHOT       1   1118.919
#
#    player_id      player_name       x       y   body_part  ... set_piece  \
# 0       7988      Boulaye Dia  40.435  11.735   LEFT FOOT  ...      None
# 1       3315  Vincent Janssen  37.974   5.910   LEFT FOOT  ...      None
# 2        428     Ismaïla Sarr  32.339  -4.970   LEFT FOOT  ...      None
# 3        214   Nampalys Mendy  34.578  -5.292  RIGHT FOOT  ...      None
# 4       8026      Daley Blind  46.561   8.293        HEAD  ...      None
#
#     shot_height shot_nature  shot_type game_event id  possession_event_id  \
# ...

# %%
df['player_name'].value_counts()
# Out:
# player_name
# Kylian Mbappé       30
# Lionel Messi        28
# Ivan Perisic        18
# Lautaro Martinez    18
# Olivier Giroud      18
#                     ..
# Sofyan Amrabat       1
# Leandro Paredes      1
# German Pezzella      1
# Nayef Aguerd         1
# Gonzalo Montiel      1
# Name: count, Length: 427, dtype: int64
